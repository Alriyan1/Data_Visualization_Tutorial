# %% [markdown]
# # pandas export
# * to csv
# * to excel
# * to html
# * to json
# * to sql

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\farde\Downloads\Deliveries.csv")

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
temp = df.groupby('batsman')['batsman_runs'].sum().reset_index()
temp.head()
# Out:
#           batsman  batsman_runs
# 0  A Ashish Reddy           280
# 1      A Chandila             4
# 2        A Chopra            53
# 3     A Choudhary            25
# 4     A Dananjaya             4

# %%
temp.to_csv(r'C:\Users\farde\Downloads\batsman_runs.csv',index=False)

# %%
df.pivot_table(index='batsman',columns='bowling_team',values='batsman_runs',aggfunc="sum")
# Out:
# bowling_team    Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# batsman
# A Ashish Reddy                 45.0              NaN             NaN
# A Chandila                      NaN              0.0             NaN
# A Chopra                        NaN             35.0             NaN
# A Choudhary                     NaN              NaN             NaN
# A Dananjaya                     NaN              NaN             NaN
# ...                             ...              ...             ...
# YV Takawale                    19.0              5.0             NaN
# Yashpal Singh                   NaN              NaN             NaN
# Younis Khan                     NaN              NaN             NaN
# Yuvraj Singh                  345.0            118.0            59.0
# Z Khan                         39.0              4.0             NaN
#
# bowling_team    Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# batsman
# ...

# %% [markdown]
# # to_excel

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
temp_df=df.groupby('batsman')['batsman_runs'].sum().reset_index()
temp_df
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4       A Dananjaya             4
# ..              ...           ...
# 511     YV Takawale           192
# 512   Yashpal Singh            47
# 513     Younis Khan             3
# 514    Yuvraj Singh          2765
# 515          Z Khan           117
#
# [516 rows x 2 columns]

# %%
temp_df.to_excel(r'C:\Users\farde\Downloads\batsman_runs.xlsx')

# %%
temp_df.to_excel(r'C:\Users\farde\Downloads\batsman_runs.xlsx',sheet_name='runs')

# %%
temp_df2=df.pivot_table(index='batsman',columns='bowling_team',values='batsman_runs',aggfunc="sum")

# %%
with pd.ExcelWriter(r'C:\Users\farde\Downloads\batsman2.xlsx') as writer:
    temp_df.to_excel(writer,sheet_name='runs')
    temp_df2.to_excel(writer,sheet_name='runs2')

# %% [markdown]
# # to_html

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df.query('batsman_runs==6').pivot_table(index='over',columns="ball",values='batsman_runs',aggfunc='count').to_html(r'C:\Users\farde\Downloads\sixes_heatmap.html')

# %% [markdown]
# # to_json

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df.groupby(['batting_team','batsman'])['batsman_runs'].sum().unstack().to_json(r'C:\Users\farde\Downloads\ipl.json')

# %% [markdown]
# # to_sql

# %%
# !pip install pymysql sqlalchemy
# Out:
# ...
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/0c/94/e4181a1f6286f545507528c78016e00065ea913276888db2262507693ce5/PyMySQL-1.1.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/45.0 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 560.2 kB/s eta 0:00:00
# ...

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root@localhost/ipl')
df.to_sql('ipl_deliveries',con=engine,if_exists='append')
# Out:
# 179078

# %%
temp_df.to_sql('batsman_runs',con=engine,if_exists='append')
# Out:
# 516
