# %% [markdown]
# <a href="https://colab.research.google.com/github/Alriyan1/Data_Visualization_Tutorial/blob/main/fetch_from_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     191.914
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     173.917
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      83.433
# 3  The true story of how businessman Oskar Schind...   1993-12-15      93.813
# 4  The defense and the prosecution have rested an...   1957-04-10      79.807
#
#    vote_average  vote_count
# 0         8.707       27103
# 1         8.690       20584
# 2         8.600       12416
# 3         8.565       15827
# 4         8.546        8629

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
  response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}".format(i))
  temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df=pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#           id                                    title  \
# 0        278                 The Shawshank Redemption
# 1        238                            The Godfather
# 2        240                    The Godfather Part II
# 3        424                         Schindler's List
# 4        389                             12 Angry Men
# ...      ...                                      ...
# 8555  631060                      Things Heard & Seen
# 8556  157433                             Pet Sematary
# 8557   39106                 Dragon Ball Z: Bio-Broly
# 8558   10040  Miss Congeniality 2: Armed and Fabulous
# 8559   56903                  Three Steps Over Heaven
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
